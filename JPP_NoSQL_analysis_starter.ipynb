# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
#1 Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
#2 assign the uk_food database to a variable name
uk_food_db = mongo['uk_food']

# %%
#3 review the collections in our database
#3.1 List the collections in the uk_food database
collection_list = uk_food_db.list_collection_names()
print("Collections in the uk_food database:")
for collection in collection_list:
    print(collection)
# Out:
# Collections in the uk_food database:
# establishments

# %%
#3.2 Iterate over each collection
for collection_name in collection_list:
    print(f"\nCollection: {collection_name}")
    
    # Access the collection
    collection = uk_food_db[collection_name]
    
    # Retrieve and display documents in the collection
    for document in collection.find():
        pprint(document)
        break
# Out:
# Collection: establishments
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6676d2e98b9d76c5040d0173'),
#  'geocode': {'latitude': Decimal128('51.086058'),
#              'longitude': Decimal128('1.196408')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %%
#4 assign the collection to a variable
establishments = uk_food_db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
#5 Define the query to find establishments with a hygiene score of 20
HS20 = {"scores.Hygiene": 20}
# Define the query to find establishments in London with RatingValue equal to 20
#query_HS20 = {"LocalAuthorityName": "London", "RatingValue": {"$gte": 20}}

# %%
#7 Display the first document in the results using pprint

# Execute the query to find the establishments with a hygiene score of 20
results = list(establishments.find(HS20))

# Display the first document using pprint
if results:
    HS_20_first_document = results[0]
    pprint(HS_20_first_document)
else:
    print("No documents found with a hygiene score of 20.")
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6676d2ea8b9d76c5040d1cb1'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
#8 Convert the result to a Pandas DataFrame
H20_df = pd.DataFrame(results)

# Display the DataFrame
pprint(H20_df)
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   6676d2ea8b9d76c5040d1cb1   110681                  0
# 1   6676d2ea8b9d76c5040d2024   612039                  0
# 2   6676d2ea8b9d76c5040d2331   730933                  0
# 3   6676d2ea8b9d76c5040d251e   172735                  0
# 4   6676d2ea8b9d76c5040d252a   172953                  0
# 5   6676d2eb8b9d76c5040d2ecd   512854                  0
# 6   6676d2eb8b9d76c5040d30ee  1537089                  0
# 7   6676d2eb8b9d76c5040d4619   155648                  0
# 8   6676d2eb8b9d76c5040d4a58  1012883                  0
# 9   6676d2eb8b9d76c5040d5285   644109                  0
# 10  6676d2eb8b9d76c5040d52dc   267034                  0
# 11  6676d2ec8b9d76c5040d5994   972876                  0
# 12  6676d2ec8b9d76c5040d6260  1417416                  0
# 13  6676d2ec8b9d76c5040d6870  1384371                  0
# 14  6676d2ec8b9d76c5040d6bcb   907216                  0
# 15  6676d2ec8b9d76c5040d713b   710382                  0
# 16  6676d2ec8b9d76c5040d71a8  1411729                  0
# 17  6676d2ec8b9d76c5040d7407  1060293                  0
# 18  6676d2ec8b9d76c5040d79ea  1243155                  0
# 19  6676d2ec8b9d76c5040d7f99  1210197                  0
# 20  6676d2ec8b9d76c5040d7fb9   108663                  0
# 21  6676d2ec8b9d76c5040d8292  1107748                  0
# 22  6676d2ec8b9d76c5040d82cc   570096                  0
# 23  6676d2ec8b9d76c5040d83d8  1500698                  0
# 24  6676d2ec8b9d76c5040d8498  1318114                  0
# 25  6676d2ec8b9d76c5040d84a5  1498084                  0
# 26  6676d2ec8b9d76c5040d8591  1063454                  0
# 27  6676d2ec8b9d76c5040d8609  1130121                  0
# 28  6676d2ed8b9d76c5040d8857   640363                  0
# 29  6676d2ed8b9d76c5040d88a1   640816                  0
# 30  6676d2ed8b9d76c5040d8912  1530599                  0
# 31  6676d2ed8b9d76c5040d8a1e   668674                  0
# 32  6676d2ed8b9d76c5040d8b07  1286585                  0
# 33  6676d2ed8b9d76c5040d8bba   971735                  0
# 34  6676d2ed8b9d76c5040d8d61  1055935                  0
# 35  6676d2ed8b9d76c5040d8f09  1177878                  0
# 36  6676d2ed8b9d76c5040d8fde  1296829                  0
# 37  6676d2ed8b9d76c5040d934e   514573                  0
# 38  6676d2ed8b9d76c5040d954b   124507                  0
# 39  6676d2ed8b9d76c5040d977c   479001                  0
# 40  6676d2ed8b9d76c5040d9954   107710                  0
#
#    LocalAuthorityBusinessID  \
# 0                      4029
# 1                 1970/FOOD
# 2                 1698/FOOD
# 3              PI/000023858
# 4              PI/000024532
# 5             12/00816/BUTH
# 6           22/00224/RESTUN
# 7               EH/00006058
# 8          17/00110/MIXED/S
# 9                     41811
# 10           11/00102/MIXED
# 11          17/00059/FOOD/S
# 12              21/00350/CP
# 13           21/00062/MIXED
# 14                   132648
# 15             PI/000194267
# 16           21/00562/MIXED
# 17             PI/000206588
# 18                    75460
# 19                    75196
# 20                    38915
# 21            19/00222/FOOD
# 22                   178447
# 23                   201759
# 24                   200845
# 25            22/00797/FOOD
# 26            18/00285/FOOD
# 27            19/00249/FOOD
# 28            10/00269/FOOD
# 29         61130/0282/0/000
# 30            22/01037/FOOD
# 31             14/00082/COM
# 32            20/00532/FOOD
# 33             17/00076/COM
# 34            18/00198/FOOD
# 35                   347294
# 36                   347449
# 37                    44243
# 38              53022999151
# 39             12/00162/COM
# 40              38127001007
#
#                                          BusinessName  \
# 0                                 The Chase Rest Home
# 1                                          Brenalwood
# 2                                       Melrose Hotel
# 3                                       Seaford Pizza
# 4                                       Golden Palace
# 5                                    Ashby's Butchers
# 6                           South Sea Express Cuisine
# 7                                       Golden Palace
# 8                                      The Tulip Tree
# 9                                               F & S
# 10                                          Longhouse
# 11  Westview Playgroup Based At Downsview Comm Pri...
# 12                        Whatever The Weather Coffee
# 13                        Kings Restaurant (Oriental)
# 14                                            Xich Lo
# 15      Asian Supermarket Ltd: T/A Best Food Wine Ltd
# 16                                             Londis
# 17                                         Costcutter
# 18                                       La Simon Ltd
# 19                                     Caribiscus Ltd
# 20                              Kennedy Fried Chicken
# 21                                          Gah Shing
# 22                                     A1 News & Wine
# 23                                      Cakes & Bakes
# 24                        Sahajanand Catering Limited
# 25                                         Sisko Cafe
# 26                             Magazin Romanesc Diana
# 27                                      Bali Maamalas
# 28                                      Angels Bakery
# 29                            Nikkis Place Restaurant
# 30                                         Chicago 30
# 31                              Samui Thai Restaurant
# 32                            Pakhtoonkhwa Restaurant
# 33                                   New Happy Garden
# 34                                          Mummy Yum
# 35                                          Gospodina
# 36                                  Leo's Bar & Grill
# 37                                         Royal Ribs
# 38                      Great Hallingbury Manor Hotel
# 39                                   The Dog And Duck
# 40                                   Oriental Cottage
#
#                          BusinessType  BusinessTypeID  \
# 0                     Caring Premises               5
# 1                     Caring Premises               5
# 2   Hotel/bed & breakfast/guest house            7842
# 3              Takeaway/sandwich shop            7844
# 4             Restaurant/Cafe/Canteen               1
# 5                   Retailers - other            4613
# 6             Restaurant/Cafe/Canteen               1
# 7              Takeaway/sandwich shop            7844
# 8             Restaurant/Cafe/Canteen               1
# 9                   Retailers - other            4613
# 10            Restaurant/Cafe/Canteen               1
# 11            Other catering premises            7841
# 12                     Mobile caterer            7846
# 13             Takeaway/sandwich shop            7844
# 14            Restaurant/Cafe/Canteen               1
# 15                  Retailers - other            4613
# 16                  Retailers - other            4613
# 17                  Retailers - other            4613
# 18                  Retailers - other            4613
# 19            Restaurant/Cafe/Canteen               1
# 20             Takeaway/sandwich shop            7844
# 21             Takeaway/sandwich shop            7844
# 22                  Retailers - other            4613
# 23             Takeaway/sandwich shop            7844
# 24            Restaurant/Cafe/Canteen               1
# 25            Restaurant/Cafe/Canteen               1
# 26                  Retailers - other            4613
# 27            Restaurant/Cafe/Canteen               1
# 28            Other catering premises            7841
# 29            Restaurant/Cafe/Canteen               1
# 30             Takeaway/sandwich shop            7844
# 31            Restaurant/Cafe/Canteen               1
# 32            Restaurant/Cafe/Canteen               1
# 33             Takeaway/sandwich shop            7844
# 34             Takeaway/sandwich shop            7844
# 35                  Retailers - other            4613
# 36            Restaurant/Cafe/Canteen               1
# 37             Takeaway/sandwich shop            7844
# 38            Restaurant/Cafe/Canteen               1
# 39                  Pub/bar/nightclub            7843
# 40             Takeaway/sandwich shop            7844
#
#                           AddressLine1               AddressLine2  \
# 0                 5-6 Southfields Road                 Eastbourne
# 1                            Hall Lane         Walton-on-the-Naze
# 2                53 Marine Parade East             Clacton On Sea
# 3                        4 High Street                    Seaford
# 4                       5 South Street                    Seaford
# 5                 777 Southchurch Road            Southend-On-Sea
# 6                  33 Alexandra Street            Southend-on-sea
# 7                        7 London Road                   Rayleigh
# 8                        3 The Village              Chiddingstone
# 9                                                  81 Southernhay
# 10                      17 London Road                  Riverhead
# 11  Downsview Community Primary School               Beech Avenue
# 12                           EMR Erith                 Manor Road
# 13                       43 Kings Road                  Brentwood
# 14                     24 Station Lane                 Hornchurch
# 15                 2 - 6 Basildon Road
# 16                5 - 7 Cranley Parade          Beaconsfield Road
# 17                         2 The Slade
# 18                                               8 Porters Avenue
# 19                                             87 Longbridge Road
# 20                                              66 Station Parade
# 21                 5 High Street South                   East Ham
# 22                                                221 Ilford Lane
# 23                                                108 Ilford Lane
# 24                                                 149 Ley Street
# 25              151 - 153 Barking Road                   East Ham
# 26               221 High Street North                   East Ham
# 27              241B High Street North                 Manor Park
# 28                    333 Barking Road                   Plaistow
# 29                    282 Barking Road                   Plaistow
# 30                  369 Katherine Road                Forest Gate
# 31                          The Kinema            Chelmsford Road
# 32                     76 Green Street                Forest Gate
# 33                   23 Stortford Road                     Dunmow
# 34                    34 West Ham Lane                  Stratford
# 35                                      345 High Road Leytonstone
# 36                                                 32 Church Lane
# 37                                                  14 Hatch Lane
# 38             Great Hallingbury Manor             Tilekiln Green
# 39                     58 Lower Street                   Stansted
# 40                       1 Mercers Row             Saffron Walden
#
#          AddressLine3  ...                LocalAuthorityEmailAddress  \
# 0         East Sussex  ...           Customerfirst@eastbourne.gov.uk
# 1               Essex  ...                fhsadmin@tendringdc.gov.uk
# 2               Essex  ...                fhsadmin@tendringdc.gov.uk
# 3         East Sussex  ...       ehealth.ldc@lewes-eastbourne.gov.uk
# 4         East Sussex  ...       ehealth.ldc@lewes-eastbourne.gov.uk
# 5               Essex  ...       EnvironmentalHealth@southend.gov.uk
# 6               Essex  ...       EnvironmentalHealth@southend.gov.uk
# 7               Essex  ...          customerservices@rochford.gov.uk
# 8                KENT  ...     environmental.health@sevenoaks.gov.uk
# 9            Basildon  ...                       ehs@basildon.gov.uk
# 10               KENT  ...     environmental.health@sevenoaks.gov.uk
# 11            Swanley  ...     environmental.health@sevenoaks.gov.uk
# 12              Erith  ...                 food.safety@bexley.gov.uk
# 13              Essex  ...                envhealth@brentwood.gov.uk
# 14                     ...      environmental.health@havering.gov.uk
# 15         Abbey Wood  ...              health@royalgreenwich.gov.uk
# 16         Mottingham  ...                       food@bromley.gov.uk
# 17          Plumstead  ...              health@royalgreenwich.gov.uk
# 18                     ...                    foodsafety@lbbd.gov.uk
# 19                     ...                    foodsafety@lbbd.gov.uk
# 20                     ...                    foodsafety@lbbd.gov.uk
# 21             London  ...                        food@newham.gov.uk
# 22                     ...           themis.skouros@redbridge.gov.uk
# 23                     ...           themis.skouros@redbridge.gov.uk
# 24                     ...           themis.skouros@redbridge.gov.uk
# 25             London  ...                        food@newham.gov.uk
# 26             London  ...                        food@newham.gov.uk
# 27             London  ...                        food@newham.gov.uk
# 28             London  ...                        food@newham.gov.uk
# 29             London  ...                        food@newham.gov.uk
# 30             London  ...                        food@newham.gov.uk
# 31             Dunmow  ...     environmentalhealth@uttlesford.gov.uk
# 32             London  ...                        food@newham.gov.uk
# 33                     ...     environmentalhealth@uttlesford.gov.uk
# 34             London  ...                        food@newham.gov.uk
# 35                     ...  environmentalhealth@walthamforest.gov.uk
# 36                     ...  environmentalhealth@walthamforest.gov.uk
# 37                     ...  environmentalhealth@walthamforest.gov.uk
# 38  Great Hallingbury  ...     environmentalhealth@uttlesford.gov.uk
# 39              Essex  ...     environmentalhealth@uttlesford.gov.uk
# 40              Essex  ...     environmentalhealth@uttlesford.gov.uk
#
#                                                scores SchemeType  \
# 0   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1   {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3   {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4   {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7   {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8   {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 10  {'Hygiene': 20, 'Structural': 25, 'ConfidenceI...       FHRS
# 11  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 12  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 13  {'Hygiene': 20, 'Structural': 25, 'ConfidenceI...       FHRS
# 14  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 15  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 16  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 17  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 18  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 19  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 20  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 21  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 22  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 23  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 24  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 25  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 26  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 27  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 28  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 29  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 30  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 31  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 32  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 33  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 34  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 35  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 36  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 37  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 38  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 39  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 40  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
#
#                                               geocode RightToReply  \
# 0       {'longitude': 0.27694, 'latitude': 50.769705}
# 1      {'longitude': 1.278721, 'latitude': 51.857536}
# 2       {'longitude': 1.15927, 'latitude': 51.789429}
# 3       {'longitude': 0.10202, 'latitude': 50.770885}
# 4      {'longitude': 0.101446, 'latitude': 50.770724}
# 5      {'longitude': 0.736349, 'latitude': 51.541448}
# 6    {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7      {'longitude': 0.602364, 'latitude': 51.591515}
# 8   {'longitude': 0.146449998021126, 'latitude': 5...
# 9       {'longitude': 0.462307, 'latitude': 51.57005}
# 10     {'longitude': 0.169685, 'latitude': 51.284795}
# 11   {'longitude': 0.1864034, 'latitude': 51.3954686}
# 12  {'longitude': 0.19265740017645, 'latitude': 51...
# 13       {'longitude': 0.2983, 'latitude': 51.618135}
# 14     {'longitude': 0.220507, 'latitude': 51.561287}
# 15   {'longitude': 0.1070469, 'latitude': 51.4848146}
# 16   {'longitude': 0.0460971, 'latitude': 51.4273993}
# 17   {'longitude': 0.0888789, 'latitude': 51.4800266}
# 18   {'longitude': 0.1300921, 'latitude': 51.5515791}
# 19     {'longitude': 0.084452, 'latitude': 51.541715}
# 20     {'longitude': 0.081616, 'latitude': 51.539293}
# 21     {'longitude': 0.055764, 'latitude': 51.531385}
# 22     {'longitude': 0.074347, 'latitude': 51.551624}
# 23   {'longitude': 0.0725645, 'latitude': 51.5540755}
# 24     {'longitude': 0.077645, 'latitude': 51.562276}
# 25     {'longitude': 0.046878, 'latitude': 51.531936}
# 26      {'longitude': 0.050713, 'latitude': 51.53963}
# 27     {'longitude': 0.050334, 'latitude': 51.541156}
# 28      {'longitude': 0.021028, 'latitude': 51.52189}
# 29     {'longitude': 0.018342, 'latitude': 51.520147}
# 30     {'longitude': 0.037523, 'latitude': 51.541658}
# 31   {'longitude': 0.3659018, 'latitude': 51.8686712}
# 32     {'longitude': 0.031959, 'latitude': 51.543994}
# 33     {'longitude': 0.360846, 'latitude': 51.873055}
# 34     {'longitude': 0.004389, 'latitude': 51.538857}
# 35     {'longitude': 0.005407, 'latitude': 51.555782}
# 36     {'longitude': 0.009101, 'latitude': 51.568245}
# 37      {'longitude': 0.006248, 'latitude': 51.61912}
# 38  {'longitude': 0.207771003246307, 'latitude': 5...
# 39     {'longitude': 0.201087, 'latitude': 51.904039}
# 40      {'longitude': 0.240491, 'latitude': 52.02328}
#
#        Distance NewRatingPending  \
# 0   4613.888288            False
# 1   4617.965824            False
# 2   4619.656144            False
# 3   4620.421725            False
# 4   4620.437179            False
# 5   4625.565258            False
# 6   4626.200132            False
# 7   4632.276890            False
# 8   4633.934041            False
# 9   4636.552523            False
# 10  4636.703065            False
# 11  4640.152449            False
# 12  4642.935252            False
# 13  4644.277277            False
# 14  4645.006441            False
# 15  4646.327125            False
# 16  4646.448256             True
# 17  4646.814122            False
# 18  4647.937955            False
# 19  4649.237462            False
# 20  4649.251920            False
# 21  4649.903794            False
# 22  4649.968842            False
# 23  4650.123644            False
# 24  4650.239432            False
# 25  4650.247785            False
# 26  4650.389971            False
# 27  4650.459698            False
# 28  4650.822100            False
# 29  4650.856226            False
# 30  4650.944835            False
# 31  4651.099995            False
# 32  4651.233130            False
# 33  4651.444488            False
# 34  4652.049760            False
# 35  4652.632190            False
# 36  4652.953922             True
# 37  4654.920996            False
# 38  4656.798774            False
# 39  4658.344880            False
# 40  4661.334349            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
# 11  {'dataSource': None, 'extractDate': '0001-01-0...
# 12  {'dataSource': None, 'extractDate': '0001-01-0...
# 13  {'dataSource': None, 'extractDate': '0001-01-0...
# 14  {'dataSource': None, 'extractDate': '0001-01-0...
# 15  {'dataSource': None, 'extractDate': '0001-01-0...
# 16  {'dataSource': None, 'extractDate': '0001-01-0...
# 17  {'dataSource': None, 'extractDate': '0001-01-0...
# 18  {'dataSource': None, 'extractDate': '0001-01-0...
# 19  {'dataSource': None, 'extractDate': '0001-01-0...
# 20  {'dataSource': None, 'extractDate': '0001-01-0...
# 21  {'dataSource': None, 'extractDate': '0001-01-0...
# 22  {'dataSource': None, 'extractDate': '0001-01-0...
# 23  {'dataSource': None, 'extractDate': '0001-01-0...
# 24  {'dataSource': None, 'extractDate': '0001-01-0...
# 25  {'dataSource': None, 'extractDate': '0001-01-0...
# 26  {'dataSource': None, 'extractDate': '0001-01-0...
# 27  {'dataSource': None, 'extractDate': '0001-01-0...
# 28  {'dataSource': None, 'extractDate': '0001-01-0...
# 29  {'dataSource': None, 'extractDate': '0001-01-0...
# 30  {'dataSource': None, 'extractDate': '0001-01-0...
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
# 33  {'dataSource': None, 'extractDate': '0001-01-0...
# 34  {'dataSource': None, 'extractDate': '0001-01-0...
# 35  {'dataSource': None, 'extractDate': '0001-01-0...
# 36  {'dataSource': None, 'extractDate': '0001-01-0...
# 37  {'dataSource': None, 'extractDate': '0001-01-0...
# 38  {'dataSource': None, 'extractDate': '0001-01-0...
# 39  {'dataSource': None, 'extractDate': '0001-01-0...
# 40  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links  \
# 0   [{'rel': 'self', 'href': 'https://api.ratings....
# 1   [{'rel': 'self', 'href': 'https://api.ratings....
# 2   [{'rel': 'self', 'href': 'https://api.ratings....
# 3   [{'rel': 'self', 'href': 'https://api.ratings....
# 4   [{'rel': 'self', 'href': 'https://api.ratings....
# 5   [{'rel': 'self', 'href': 'https://api.ratings....
# 6   [{'rel': 'self', 'href': 'https://api.ratings....
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 11  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 12  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 13  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 14  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 15  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 16  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 17  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 18  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 19  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 20  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 21  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 22  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 23  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 24  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 25  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 26  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 27  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 28  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 29  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 30  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 33  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 34  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 35  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 36  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 37  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 38  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 39  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 40  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                                    CO
# 0   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 1   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 2   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 3   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 4   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 5   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 6   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 7   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 8   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 9   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 10  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 11  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 12  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 13  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 14  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 15  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 16  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 17  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 18  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 19  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 20  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 21  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 22  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 23  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 24  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 25  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 26  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 27  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 28  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 29  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 30  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 31  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 32  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 33  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 34  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 35  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 36  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 37  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 38  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 39  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 40  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
#
# [41 rows x 29 columns]

# %%
#9 Display the number of rows in the DataFrame
pprint(f"Number of rows in the DataFrame: {len(H20_df)}")
# Out:
# 'Number of rows in the DataFrame: 41'

# %%
#10 Display the first 10 rows of the DataFrame
print(H20_df.head(10))
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6676d2ea8b9d76c5040d1cb1   110681                  0
# 1  6676d2ea8b9d76c5040d2024   612039                  0
# 2  6676d2ea8b9d76c5040d2331   730933                  0
# 3  6676d2ea8b9d76c5040d251e   172735                  0
# 4  6676d2ea8b9d76c5040d252a   172953                  0
# 5  6676d2eb8b9d76c5040d2ecd   512854                  0
# 6  6676d2eb8b9d76c5040d30ee  1537089                  0
# 7  6676d2eb8b9d76c5040d4619   155648                  0
# 8  6676d2eb8b9d76c5040d4a58  1012883                  0
# 9  6676d2eb8b9d76c5040d5285   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                                   CO
# 0  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 1  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 2  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 3  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 4  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 5  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 6  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 7  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 8  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 9  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
#
# [10 rows x 29 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
#11 Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query2 = {"RatingValue": 4}
# Define the query to find establishments in London with RatingValue greater than or equal to 4
query2 = {"LocalAuthorityName": {'$regex':'London'}, "RatingValue": {"$gte": 4}}

# %%
#12 Use count_documents to display the number of documents in the result
num_establishments_london = establishments.count_documents(query2)

# %%
#13 Display the first document in the results using pprint
pprint(f"Number of establishments in London with RatingValue >= 4: {num_establishments_london}")
# Out:
# 'Number of establishments in London with RatingValue >= 4: 33'

# %%
#14 Convert the result to a Pandas DataFrame
# Convert the count result to a Pandas DataFrame
num_establishments_london_df = pd.DataFrame(establishments.find(query2))

# Display the DataFrame
print(num_establishments_london_df)
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   6676d2eb8b9d76c5040d36c1   621707                  0
# 1   6676d2eb8b9d76c5040d39e2  1130836                  0
# 2   6676d2eb8b9d76c5040d4532   293783                  0
# 3   6676d2eb8b9d76c5040d5333   294474                  0
# 4   6676d2eb8b9d76c5040d535a  1315095                  0
# 5   6676d2ec8b9d76c5040d5a3b   294900                  0
# 6   6676d2ec8b9d76c5040d7b49   293756                  0
# 7   6676d2ec8b9d76c5040d7f12   878523                  0
# 8   6676d2ec8b9d76c5040d7f28   294606                  0
# 9   6676d2ec8b9d76c5040d7f2a   293772                  0
# 10  6676d2ec8b9d76c5040d7f2b   295107                  0
# 11  6676d2ec8b9d76c5040d8107   294523                  0
# 12  6676d2ec8b9d76c5040d810a   294616                  0
# 13  6676d2ec8b9d76c5040d83ab  1427985                  0
# 14  6676d2ec8b9d76c5040d85b1   934211                  0
# 15  6676d2ec8b9d76c5040d85da  1392440                  0
# 16  6676d2ec8b9d76c5040d85ec   558640                  0
# 17  6676d2ed8b9d76c5040d87a0  1498024                  0
# 18  6676d2ed8b9d76c5040d87ed  1090020                  0
# 19  6676d2ed8b9d76c5040d87ee  1090017                  0
# 20  6676d2ed8b9d76c5040d87ef  1090023                  0
# 21  6676d2ed8b9d76c5040d87f2  1090018                  0
# 22  6676d2ed8b9d76c5040d87f3  1090027                  0
# 23  6676d2ed8b9d76c5040d87f4  1090025                  0
# 24  6676d2ed8b9d76c5040d87f5  1090028                  0
# 25  6676d2ed8b9d76c5040d87f6  1090024                  0
# 26  6676d2ed8b9d76c5040d87f8  1090016                  0
# 27  6676d2ed8b9d76c5040d87f9  1450220                  0
# 28  6676d2ed8b9d76c5040d87fa  1090021                  0
# 29  6676d2ed8b9d76c5040d8800  1090022                  0
# 30  6676d2ed8b9d76c5040d8801   293758                  0
# 31  6676d2ed8b9d76c5040d8802  1090026                  0
# 32  6676d2ed8b9d76c5040d8803  1090019                  0
#
#    LocalAuthorityBusinessID                          BusinessName  \
# 0              PI/000025307                             Charlie's
# 1              PI/000034075               Mv City Cruises Erasmus
# 2              PI/000002614             Benfleet Motor Yacht Club
# 3              PI/000014647              Tilbury Seafarers Centre
# 4              PI/000036464  Coombs Catering t/a The Lock and Key
# 5              PI/000019066                            Mv Valulla
# 6              PI/000002538                         Tereza Joanne
# 7              PI/000029844                      Brick Lane Brews
# 8              PI/000016185                              WH Smith
# 9              PI/000002585         The Nuance Group (UK) Limited
# 10             PI/000020749                      City Bar & Grill
# 11             PI/000015222                            Jet Centre
# 12             PI/000016269                            Caffè Nero
# 13             PI/000037871                Mv Sunborn Yacht Hotel
# 14             PI/000030457                     Good Hotel London
# 15             PI/000037382                         La Nonna lina
# 16             PI/000024155             Wake Up Docklands Limited
# 17             PI/000038347                      MV Venus Clipper
# 18             PI/000033476                    MV Typhoon clipper
# 19             PI/000033472                       MV Moon clipper
# 20             PI/000033479                    MV Jupiter clipper
# 21             PI/000033473                    MV Mercury clipper
# 22             PI/000033483                    MV Cyclone clipper
# 23             PI/000033481                  MV Hurricane clipper
# 24             PI/000033484                    MV Neptune clipper
# 25             PI/000033480                     MV Galaxy clipper
# 26             PI/000033470                        MV Sun clipper
# 27             PI/000038259                       Canary Wharf 1V
# 28             PI/000033477                    MV Monsoon clipper
# 29             PI/000033478                     MV Meteor clipper
# 30             PI/000002546                      Mv Storm Clipper
# 31             PI/000033482                     MV Aurora clipper
# 32             PI/000033475                    MV Tornado clipper
#
#                          BusinessType  BusinessTypeID  \
# 0             Other catering premises            7841
# 1             Other catering premises            7841
# 2             Other catering premises            7841
# 3             Restaurant/Cafe/Canteen               1
# 4             Restaurant/Cafe/Canteen               1
# 5             Other catering premises            7841
# 6             Other catering premises            7841
# 7             Restaurant/Cafe/Canteen               1
# 8                   Retailers - other            4613
# 9                   Retailers - other            4613
# 10            Restaurant/Cafe/Canteen               1
# 11            Restaurant/Cafe/Canteen               1
# 12            Restaurant/Cafe/Canteen               1
# 13  Hotel/bed & breakfast/guest house            7842
# 14            Other catering premises            7841
# 15            Other catering premises            7841
# 16            Other catering premises            7841
# 17            Other catering premises            7841
# 18            Other catering premises            7841
# 19            Other catering premises            7841
# 20            Other catering premises            7841
# 21            Other catering premises            7841
# 22            Other catering premises            7841
# 23            Other catering premises            7841
# 24            Other catering premises            7841
# 25            Other catering premises            7841
# 26            Other catering premises            7841
# 27            Other catering premises            7841
# 28            Other catering premises            7841
# 29            Other catering premises            7841
# 30            Other catering premises            7841
# 31            Other catering premises            7841
# 32            Other catering premises            7841
#
#                                          AddressLine1  \
# 0          Oak Apple Farm Building 103 Sheernes Docks
# 1                                  Cherry Garden Pier
# 2                                          Ferry Road
# 3                           Tenants Row Tilbury Docks
# 4                                   Leslie Ford House
# 5   Reeds River Cruises LtdKings ReachRiver Thames...
# 6   Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                        Air side London City Airport
# 8                                 London City Airport
# 9                   Duty Free Shop Passenger Terminal
# 10                      London City Airport (Airside)
# 11                                London City Airport
# 12       London City Airport Airside Departure Lounge
# 13                                    Western Gateway
# 14                Western Gateway Royal Victoria Dock
# 15                                          Dock Road
# 16                 Western Beach Royal Victoria Docks
# 17                                 Trinity Buoy Wharf
# 18     Thames Clippers Unit 12 The Riverside Building
# 19             Thames Clippers 3rd flr Clippers House
# 20     Thames Clippers Unit 12 The Riverside Building
# 21             Thames Clippers 3rd flr Clippers House
# 22     Thames Clippers Unit 12 The Riverside Building
# 23     Thames Clippers Unit 12 The Riverside Building
# 24     Thames Clippers Unit 12 The Riverside Building
# 25     Thames Clippers Unit 12 The Riverside Building
# 26             Thames Clippers 3rd flr Clippers House
# 27                                 Trinity Buoy Wharf
# 28     Thames Clippers Unit 12 The Riverside Building
# 29     Thames Clippers Unit 12 The Riverside Building
# 30     Thames Clippers Unit 12 The Riverside Building
# 31     Thames Clippers Unit 12 The Riverside Building
# 32     Thames Clippers Unit 12 The Riverside Building
#
#                                     AddressLine2 AddressLine3  ...  \
# 0                                    Sheppy Kent               ...
# 1               Cherry Garden Street Rotherhithe     Charlton  ...
# 2                           South Benfleet Essex               ...
# 3                                  Tilbury Essex               ...
# 4                                        Tilbury     Charlton  ...
# 5                                         London               ...
# 6                                         London               ...
# 7                                         London               ...
# 8                              Silvertown London               ...
# 9           London City AirportRoyal DocksLondon               ...
# 10                                        London               ...
# 11                            Royal Docks London               ...
# 12                            Royal Docks London               ...
# 13                           Royal Victoria Dock               ...
# 14  Floating Platform next to Emirates Cable Car               ...
# 15                                        London     Charlton  ...
# 16                                        London     Charlton  ...
# 17                                 Orchard Place               ...
# 18    64 Orchard Place Trinity Buoy Wharf London               ...
# 19       Orchard Place Trinity Buoy Wharf London               ...
# 20    64 Orchard Place Trinity Buoy Wharf London               ...
# 21       Orchard Place Trinity Buoy Wharf London               ...
# 22    64 Orchard Place Trinity Buoy Wharf London               ...
# 23    64 Orchard Place Trinity Buoy Wharf London               ...
# 24    64 Orchard Place Trinity Buoy Wharf London               ...
# 25    64 Orchard Place Trinity Buoy Wharf London               ...
# 26       Orchard Place Trinity Buoy Wharf London               ...
# 27                              64 Orchard Place               ...
# 28    64 Orchard Place Trinity Buoy Wharf London               ...
# 29    64 Orchard Place Trinity Buoy Wharf London               ...
# 30    64 Orchard Place Trinity Buoy Wharf London               ...
# 31    64 Orchard Place Trinity Buoy Wharf London               ...
# 32    64 Orchard Place Trinity Buoy Wharf London               ...
#
#               LocalAuthorityEmailAddress  \
# 0   publicprotection@cityoflondon.gov.uk
# 1   publicprotection@cityoflondon.gov.uk
# 2   publicprotection@cityoflondon.gov.uk
# 3   publicprotection@cityoflondon.gov.uk
# 4   publicprotection@cityoflondon.gov.uk
# 5   publicprotection@cityoflondon.gov.uk
# 6   publicprotection@cityoflondon.gov.uk
# 7   publicprotection@cityoflondon.gov.uk
# 8   publicprotection@cityoflondon.gov.uk
# 9   publicprotection@cityoflondon.gov.uk
# 10  publicprotection@cityoflondon.gov.uk
# 11  publicprotection@cityoflondon.gov.uk
# 12  publicprotection@cityoflondon.gov.uk
# 13  publicprotection@cityoflondon.gov.uk
# 14  publicprotection@cityoflondon.gov.uk
# 15  publicprotection@cityoflondon.gov.uk
# 16  publicprotection@cityoflondon.gov.uk
# 17  publicprotection@cityoflondon.gov.uk
# 18  publicprotection@cityoflondon.gov.uk
# 19  publicprotection@cityoflondon.gov.uk
# 20  publicprotection@cityoflondon.gov.uk
# 21  publicprotection@cityoflondon.gov.uk
# 22  publicprotection@cityoflondon.gov.uk
# 23  publicprotection@cityoflondon.gov.uk
# 24  publicprotection@cityoflondon.gov.uk
# 25  publicprotection@cityoflondon.gov.uk
# 26  publicprotection@cityoflondon.gov.uk
# 27  publicprotection@cityoflondon.gov.uk
# 28  publicprotection@cityoflondon.gov.uk
# 29  publicprotection@cityoflondon.gov.uk
# 30  publicprotection@cityoflondon.gov.uk
# 31  publicprotection@cityoflondon.gov.uk
# 32  publicprotection@cityoflondon.gov.uk
#
#                                                scores SchemeType  \
# 0   {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7   {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 8   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 10  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 11  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 12  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 13  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 14  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 15  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 16  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 17  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 18  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 19  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 20  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 21  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 22  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 23  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 24  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 25  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 26  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 27  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 28  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 29  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 30  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 31  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 32  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                               geocode RightToReply  \
# 0      {'longitude': 0.508551, 'latitude': 51.369321}
# 1   {'longitude': 0.249255999922752, 'latitude': 5...
# 2      {'longitude': 0.561954, 'latitude': 51.543831}
# 3      {'longitude': 0.346325, 'latitude': 51.464078}
# 4   {'longitude': 0.346336990594864, 'latitude': 5...
# 5      {'longitude': 0.287555, 'latitude': 51.504071}
# 6      {'longitude': 0.069286, 'latitude': 51.501121}
# 7      {'longitude': 0.048006, 'latitude': 51.503733}
# 8   {'longitude': 0.0479655750095844, 'latitude': ...
# 9      {'longitude': 0.047966, 'latitude': 51.504112}
# 10  {'longitude': 0.0479655750095844, 'latitude': ...
# 11  {'longitude': 0.0405181497335434, 'latitude': ...
# 12     {'longitude': 0.040518, 'latitude': 51.504808}
# 13      {'longitude': 0.027107, 'latitude': 51.50817}
# 14      {'longitude': 0.01792, 'latitude': 51.507681}
# 15  {'longitude': 0.0157549995929003, 'latitude': ...
# 16     {'longitude': 0.015742, 'latitude': 51.505992}
# 17  {'longitude': 0.00890800673629534, 'latitude':...
# 18     {'longitude': 0.007816, 'latitude': 51.508259}
# 19  {'longitude': 0.0078159999102354, 'latitude': ...
# 20     {'longitude': 0.007816, 'latitude': 51.508259}
# 21  {'longitude': 0.0078159999102354, 'latitude': ...
# 22     {'longitude': 0.007816, 'latitude': 51.508259}
# 23     {'longitude': 0.007816, 'latitude': 51.508259}
# 24     {'longitude': 0.007816, 'latitude': 51.508259}
# 25     {'longitude': 0.007816, 'latitude': 51.508259}
# 26  {'longitude': 0.0078159999102354, 'latitude': ...
# 27     {'longitude': 0.007815, 'latitude': 51.508259}
# 28     {'longitude': 0.007816, 'latitude': 51.508259}
# 29     {'longitude': 0.007816, 'latitude': 51.508259}
# 30     {'longitude': 0.007816, 'latitude': 51.508259}
# 31     {'longitude': 0.007816, 'latitude': 51.508259}
# 32     {'longitude': 0.007816, 'latitude': 51.508259}
#
#        Distance NewRatingPending  \
# 0   4627.439468            False
# 1   4627.873179            False
# 2   4631.968418            False
# 3   4636.847650            False
# 4   4636.846754            False
# 5   4640.460834            False
# 6   4648.301822            False
# 7   4649.173485            False
# 8   4649.188850            False
# 9   4649.188826            False
# 10  4649.188850            False
# 11  4649.485870            False
# 12  4649.485929            False
# 13  4650.098130            False
# 14  4650.415301            False
# 15  4650.432066            False
# 16  4650.432926            False
# 17  4650.747349            False
# 18  4650.805008            False
# 19  4650.805001            False
# 20  4650.805008            False
# 21  4650.805001            False
# 22  4650.805008            False
# 23  4650.805008            False
# 24  4650.805008            False
# 25  4650.805008            False
# 26  4650.805001            False
# 27  4650.805044            False
# 28  4650.805008            False
# 29  4650.805008            False
# 30  4650.805008            False
# 31  4650.805008            False
# 32  4650.805008            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
# 11  {'dataSource': None, 'extractDate': '0001-01-0...
# 12  {'dataSource': None, 'extractDate': '0001-01-0...
# 13  {'dataSource': None, 'extractDate': '0001-01-0...
# 14  {'dataSource': None, 'extractDate': '0001-01-0...
# 15  {'dataSource': None, 'extractDate': '0001-01-0...
# 16  {'dataSource': None, 'extractDate': '0001-01-0...
# 17  {'dataSource': None, 'extractDate': '0001-01-0...
# 18  {'dataSource': None, 'extractDate': '0001-01-0...
# 19  {'dataSource': None, 'extractDate': '0001-01-0...
# 20  {'dataSource': None, 'extractDate': '0001-01-0...
# 21  {'dataSource': None, 'extractDate': '0001-01-0...
# 22  {'dataSource': None, 'extractDate': '0001-01-0...
# 23  {'dataSource': None, 'extractDate': '0001-01-0...
# 24  {'dataSource': None, 'extractDate': '0001-01-0...
# 25  {'dataSource': None, 'extractDate': '0001-01-0...
# 26  {'dataSource': None, 'extractDate': '0001-01-0...
# 27  {'dataSource': None, 'extractDate': '0001-01-0...
# 28  {'dataSource': None, 'extractDate': '0001-01-0...
# 29  {'dataSource': None, 'extractDate': '0001-01-0...
# 30  {'dataSource': None, 'extractDate': '0001-01-0...
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links  \
# 0   [{'rel': 'self', 'href': 'https://api.ratings....
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 11  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 12  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 13  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 14  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 15  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 16  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 17  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 18  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 19  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 20  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 21  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 22  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 23  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 24  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 25  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 26  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 27  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 28  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 29  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 30  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                                    CO
# 0   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 1   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 2   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 3   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 4   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 5   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 6   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 7   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 8   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 9   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 10  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 11  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 12  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 13  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 14  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 15  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 16  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 17  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 18  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 19  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 20  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 21  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 22  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 23  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 24  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 25  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 26  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 27  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 28  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 29  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 30  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 31  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 32  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
#
# [33 rows x 29 columns]

# %%
#15 Display the number of rows in the DataFrame
# Display the number of rows in the DataFrame
num_rows = num_establishments_london_df.shape[0]
# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame:", num_rows)
# Out:
# Number of rows in the DataFrame: 33

# %%
#16 Display the first 10 rows of the DataFrame
pprint(num_establishments_london_df.head(10))
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6676d2eb8b9d76c5040d36c1   621707                  0
# 1  6676d2eb8b9d76c5040d39e2  1130836                  0
# 2  6676d2eb8b9d76c5040d4532   293783                  0
# 3  6676d2eb8b9d76c5040d5333   294474                  0
# 4  6676d2eb8b9d76c5040d535a  1315095                  0
# 5  6676d2ec8b9d76c5040d5a3b   294900                  0
# 6  6676d2ec8b9d76c5040d7b49   293756                  0
# 7  6676d2ec8b9d76c5040d7f12   878523                  0
# 8  6676d2ec8b9d76c5040d7f28   294606                  0
# 9  6676d2ec8b9d76c5040d7f2a   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# 4             PI/000036464  Coombs Catering t/a The Lock and Key
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000016185                              WH Smith
# 9             PI/000002585         The Nuance Group (UK) Limited
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                          Tenants Row Tilbury Docks
# 4                                  Leslie Ford House
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                                London City Airport
# 9                  Duty Free Shop Passenger Terminal
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                         Tilbury Essex               ...
# 4                               Tilbury     Charlton  ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8                     Silvertown London               ...
# 9  London City AirportRoyal DocksLondon               ...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3     {'longitude': 0.346325, 'latitude': 51.464078}
# 4  {'longitude': 0.346336990594864, 'latitude': 5...
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8  {'longitude': 0.0479655750095844, 'latitude': ...
# 9     {'longitude': 0.047966, 'latitude': 51.504112}
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.847650            False
# 4  4636.846754            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188850            False
# 9  4649.188826            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                                   CO
# 0  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 1  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 2  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 3  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 4  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 5  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 6  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 7  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 8  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 9  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
#
# [10 rows x 29 columns]

# %%
num_establishments_london_df
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   6676d2eb8b9d76c5040d36c1   621707                  0
# 1   6676d2eb8b9d76c5040d39e2  1130836                  0
# 2   6676d2eb8b9d76c5040d4532   293783                  0
# 3   6676d2eb8b9d76c5040d5333   294474                  0
# 4   6676d2eb8b9d76c5040d535a  1315095                  0
# 5   6676d2ec8b9d76c5040d5a3b   294900                  0
# 6   6676d2ec8b9d76c5040d7b49   293756                  0
# 7   6676d2ec8b9d76c5040d7f12   878523                  0
# 8   6676d2ec8b9d76c5040d7f28   294606                  0
# 9   6676d2ec8b9d76c5040d7f2a   293772                  0
# 10  6676d2ec8b9d76c5040d7f2b   295107                  0
# 11  6676d2ec8b9d76c5040d8107   294523                  0
# 12  6676d2ec8b9d76c5040d810a   294616                  0
# 13  6676d2ec8b9d76c5040d83ab  1427985                  0
# 14  6676d2ec8b9d76c5040d85b1   934211                  0
# 15  6676d2ec8b9d76c5040d85da  1392440                  0
# 16  6676d2ec8b9d76c5040d85ec   558640                  0
# 17  6676d2ed8b9d76c5040d87a0  1498024                  0
# 18  6676d2ed8b9d76c5040d87ed  1090020                  0
# 19  6676d2ed8b9d76c5040d87ee  1090017                  0
# 20  6676d2ed8b9d76c5040d87ef  1090023                  0
# 21  6676d2ed8b9d76c5040d87f2  1090018                  0
# 22  6676d2ed8b9d76c5040d87f3  1090027                  0
# 23  6676d2ed8b9d76c5040d87f4  1090025                  0
# 24  6676d2ed8b9d76c5040d87f5  1090028                  0
# 25  6676d2ed8b9d76c5040d87f6  1090024                  0
# 26  6676d2ed8b9d76c5040d87f8  1090016                  0
# 27  6676d2ed8b9d76c5040d87f9  1450220                  0
# 28  6676d2ed8b9d76c5040d87fa  1090021                  0
# 29  6676d2ed8b9d76c5040d8800  1090022                  0
# 30  6676d2ed8b9d76c5040d8801   293758                  0
# 31  6676d2ed8b9d76c5040d8802  1090026                  0
# 32  6676d2ed8b9d76c5040d8803  1090019                  0
#
#    LocalAuthorityBusinessID                          BusinessName  \
# 0              PI/000025307                             Charlie's
# 1              PI/000034075               Mv City Cruises Erasmus
# 2              PI/000002614             Benfleet Motor Yacht Club
# 3              PI/000014647              Tilbury Seafarers Centre
# 4              PI/000036464  Coombs Catering t/a The Lock and Key
# 5              PI/000019066                            Mv Valulla
# 6              PI/000002538                         Tereza Joanne
# 7              PI/000029844                      Brick Lane Brews
# 8              PI/000016185                              WH Smith
# 9              PI/000002585         The Nuance Group (UK) Limited
# 10             PI/000020749                      City Bar & Grill
# 11             PI/000015222                            Jet Centre
# 12             PI/000016269                            Caffè Nero
# 13             PI/000037871                Mv Sunborn Yacht Hotel
# 14             PI/000030457                     Good Hotel London
# 15             PI/000037382                         La Nonna lina
# 16             PI/000024155             Wake Up Docklands Limited
# 17             PI/000038347                      MV Venus Clipper
# 18             PI/000033476                    MV Typhoon clipper
# 19             PI/000033472                       MV Moon clipper
# 20             PI/000033479                    MV Jupiter clipper
# 21             PI/000033473                    MV Mercury clipper
# 22             PI/000033483                    MV Cyclone clipper
# 23             PI/000033481                  MV Hurricane clipper
# 24             PI/000033484                    MV Neptune clipper
# 25             PI/000033480                     MV Galaxy clipper
# 26             PI/000033470                        MV Sun clipper
# 27             PI/000038259                       Canary Wharf 1V
# 28             PI/000033477                    MV Monsoon clipper
# 29             PI/000033478                     MV Meteor clipper
# 30             PI/000002546                      Mv Storm Clipper
# 31             PI/000033482                     MV Aurora clipper
# 32             PI/000033475                    MV Tornado clipper
#
#                          BusinessType  BusinessTypeID  \
# 0             Other catering premises            7841
# 1             Other catering premises            7841
# 2             Other catering premises            7841
# 3             Restaurant/Cafe/Canteen               1
# 4             Restaurant/Cafe/Canteen               1
# 5             Other catering premises            7841
# 6             Other catering premises            7841
# 7             Restaurant/Cafe/Canteen               1
# 8                   Retailers - other            4613
# 9                   Retailers - other            4613
# 10            Restaurant/Cafe/Canteen               1
# 11            Restaurant/Cafe/Canteen               1
# 12            Restaurant/Cafe/Canteen               1
# 13  Hotel/bed & breakfast/guest house            7842
# 14            Other catering premises            7841
# 15            Other catering premises            7841
# 16            Other catering premises            7841
# 17            Other catering premises            7841
# 18            Other catering premises            7841
# 19            Other catering premises            7841
# 20            Other catering premises            7841
# 21            Other catering premises            7841
# 22            Other catering premises            7841
# 23            Other catering premises            7841
# 24            Other catering premises            7841
# 25            Other catering premises            7841
# 26            Other catering premises            7841
# 27            Other catering premises            7841
# 28            Other catering premises            7841
# 29            Other catering premises            7841
# 30            Other catering premises            7841
# 31            Other catering premises            7841
# 32            Other catering premises            7841
#
#                                          AddressLine1  \
# 0          Oak Apple Farm Building 103 Sheernes Docks
# 1                                  Cherry Garden Pier
# 2                                          Ferry Road
# 3                           Tenants Row Tilbury Docks
# 4                                   Leslie Ford House
# 5   Reeds River Cruises LtdKings ReachRiver Thames...
# 6   Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                        Air side London City Airport
# 8                                 London City Airport
# 9                   Duty Free Shop Passenger Terminal
# 10                      London City Airport (Airside)
# 11                                London City Airport
# 12       London City Airport Airside Departure Lounge
# 13                                    Western Gateway
# 14                Western Gateway Royal Victoria Dock
# 15                                          Dock Road
# 16                 Western Beach Royal Victoria Docks
# 17                                 Trinity Buoy Wharf
# 18     Thames Clippers Unit 12 The Riverside Building
# 19             Thames Clippers 3rd flr Clippers House
# 20     Thames Clippers Unit 12 The Riverside Building
# 21             Thames Clippers 3rd flr Clippers House
# 22     Thames Clippers Unit 12 The Riverside Building
# 23     Thames Clippers Unit 12 The Riverside Building
# 24     Thames Clippers Unit 12 The Riverside Building
# 25     Thames Clippers Unit 12 The Riverside Building
# 26             Thames Clippers 3rd flr Clippers House
# 27                                 Trinity Buoy Wharf
# 28     Thames Clippers Unit 12 The Riverside Building
# 29     Thames Clippers Unit 12 The Riverside Building
# 30     Thames Clippers Unit 12 The Riverside Building
# 31     Thames Clippers Unit 12 The Riverside Building
# 32     Thames Clippers Unit 12 The Riverside Building
#
#                                     AddressLine2 AddressLine3  ...  \
# 0                                    Sheppy Kent               ...
# 1               Cherry Garden Street Rotherhithe     Charlton  ...
# 2                           South Benfleet Essex               ...
# 3                                  Tilbury Essex               ...
# 4                                        Tilbury     Charlton  ...
# 5                                         London               ...
# 6                                         London               ...
# 7                                         London               ...
# 8                              Silvertown London               ...
# 9           London City AirportRoyal DocksLondon               ...
# 10                                        London               ...
# 11                            Royal Docks London               ...
# 12                            Royal Docks London               ...
# 13                           Royal Victoria Dock               ...
# 14  Floating Platform next to Emirates Cable Car               ...
# 15                                        London     Charlton  ...
# 16                                        London     Charlton  ...
# 17                                 Orchard Place               ...
# 18    64 Orchard Place Trinity Buoy Wharf London               ...
# 19       Orchard Place Trinity Buoy Wharf London               ...
# 20    64 Orchard Place Trinity Buoy Wharf London               ...
# 21       Orchard Place Trinity Buoy Wharf London               ...
# 22    64 Orchard Place Trinity Buoy Wharf London               ...
# 23    64 Orchard Place Trinity Buoy Wharf London               ...
# 24    64 Orchard Place Trinity Buoy Wharf London               ...
# 25    64 Orchard Place Trinity Buoy Wharf London               ...
# 26       Orchard Place Trinity Buoy Wharf London               ...
# 27                              64 Orchard Place               ...
# 28    64 Orchard Place Trinity Buoy Wharf London               ...
# 29    64 Orchard Place Trinity Buoy Wharf London               ...
# 30    64 Orchard Place Trinity Buoy Wharf London               ...
# 31    64 Orchard Place Trinity Buoy Wharf London               ...
# 32    64 Orchard Place Trinity Buoy Wharf London               ...
#
#               LocalAuthorityEmailAddress  \
# 0   publicprotection@cityoflondon.gov.uk
# 1   publicprotection@cityoflondon.gov.uk
# 2   publicprotection@cityoflondon.gov.uk
# 3   publicprotection@cityoflondon.gov.uk
# 4   publicprotection@cityoflondon.gov.uk
# 5   publicprotection@cityoflondon.gov.uk
# 6   publicprotection@cityoflondon.gov.uk
# 7   publicprotection@cityoflondon.gov.uk
# 8   publicprotection@cityoflondon.gov.uk
# 9   publicprotection@cityoflondon.gov.uk
# 10  publicprotection@cityoflondon.gov.uk
# 11  publicprotection@cityoflondon.gov.uk
# 12  publicprotection@cityoflondon.gov.uk
# 13  publicprotection@cityoflondon.gov.uk
# 14  publicprotection@cityoflondon.gov.uk
# 15  publicprotection@cityoflondon.gov.uk
# 16  publicprotection@cityoflondon.gov.uk
# 17  publicprotection@cityoflondon.gov.uk
# 18  publicprotection@cityoflondon.gov.uk
# 19  publicprotection@cityoflondon.gov.uk
# 20  publicprotection@cityoflondon.gov.uk
# 21  publicprotection@cityoflondon.gov.uk
# 22  publicprotection@cityoflondon.gov.uk
# 23  publicprotection@cityoflondon.gov.uk
# 24  publicprotection@cityoflondon.gov.uk
# 25  publicprotection@cityoflondon.gov.uk
# 26  publicprotection@cityoflondon.gov.uk
# 27  publicprotection@cityoflondon.gov.uk
# 28  publicprotection@cityoflondon.gov.uk
# 29  publicprotection@cityoflondon.gov.uk
# 30  publicprotection@cityoflondon.gov.uk
# 31  publicprotection@cityoflondon.gov.uk
# 32  publicprotection@cityoflondon.gov.uk
#
#                                                scores SchemeType  \
# 0   {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7   {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 8   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 10  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 11  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 12  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 13  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 14  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 15  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 16  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 17  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 18  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 19  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 20  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 21  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 22  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 23  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 24  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 25  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 26  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 27  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 28  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 29  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 30  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 31  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 32  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                               geocode RightToReply  \
# 0      {'longitude': 0.508551, 'latitude': 51.369321}
# 1   {'longitude': 0.249255999922752, 'latitude': 5...
# 2      {'longitude': 0.561954, 'latitude': 51.543831}
# 3      {'longitude': 0.346325, 'latitude': 51.464078}
# 4   {'longitude': 0.346336990594864, 'latitude': 5...
# 5      {'longitude': 0.287555, 'latitude': 51.504071}
# 6      {'longitude': 0.069286, 'latitude': 51.501121}
# 7      {'longitude': 0.048006, 'latitude': 51.503733}
# 8   {'longitude': 0.0479655750095844, 'latitude': ...
# 9      {'longitude': 0.047966, 'latitude': 51.504112}
# 10  {'longitude': 0.0479655750095844, 'latitude': ...
# 11  {'longitude': 0.0405181497335434, 'latitude': ...
# 12     {'longitude': 0.040518, 'latitude': 51.504808}
# 13      {'longitude': 0.027107, 'latitude': 51.50817}
# 14      {'longitude': 0.01792, 'latitude': 51.507681}
# 15  {'longitude': 0.0157549995929003, 'latitude': ...
# 16     {'longitude': 0.015742, 'latitude': 51.505992}
# 17  {'longitude': 0.00890800673629534, 'latitude':...
# 18     {'longitude': 0.007816, 'latitude': 51.508259}
# 19  {'longitude': 0.0078159999102354, 'latitude': ...
# 20     {'longitude': 0.007816, 'latitude': 51.508259}
# 21  {'longitude': 0.0078159999102354, 'latitude': ...
# 22     {'longitude': 0.007816, 'latitude': 51.508259}
# 23     {'longitude': 0.007816, 'latitude': 51.508259}
# 24     {'longitude': 0.007816, 'latitude': 51.508259}
# 25     {'longitude': 0.007816, 'latitude': 51.508259}
# 26  {'longitude': 0.0078159999102354, 'latitude': ...
# 27     {'longitude': 0.007815, 'latitude': 51.508259}
# 28     {'longitude': 0.007816, 'latitude': 51.508259}
# 29     {'longitude': 0.007816, 'latitude': 51.508259}
# 30     {'longitude': 0.007816, 'latitude': 51.508259}
# 31     {'longitude': 0.007816, 'latitude': 51.508259}
# 32     {'longitude': 0.007816, 'latitude': 51.508259}
#
#        Distance NewRatingPending  \
# 0   4627.439468            False
# 1   4627.873179            False
# 2   4631.968418            False
# 3   4636.847650            False
# 4   4636.846754            False
# 5   4640.460834            False
# 6   4648.301822            False
# 7   4649.173485            False
# 8   4649.188850            False
# 9   4649.188826            False
# 10  4649.188850            False
# 11  4649.485870            False
# 12  4649.485929            False
# 13  4650.098130            False
# 14  4650.415301            False
# 15  4650.432066            False
# 16  4650.432926            False
# 17  4650.747349            False
# 18  4650.805008            False
# 19  4650.805001            False
# 20  4650.805008            False
# 21  4650.805001            False
# 22  4650.805008            False
# 23  4650.805008            False
# 24  4650.805008            False
# 25  4650.805008            False
# 26  4650.805001            False
# 27  4650.805044            False
# 28  4650.805008            False
# 29  4650.805008            False
# 30  4650.805008            False
# 31  4650.805008            False
# 32  4650.805008            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
# 11  {'dataSource': None, 'extractDate': '0001-01-0...
# 12  {'dataSource': None, 'extractDate': '0001-01-0...
# 13  {'dataSource': None, 'extractDate': '0001-01-0...
# 14  {'dataSource': None, 'extractDate': '0001-01-0...
# 15  {'dataSource': None, 'extractDate': '0001-01-0...
# 16  {'dataSource': None, 'extractDate': '0001-01-0...
# 17  {'dataSource': None, 'extractDate': '0001-01-0...
# 18  {'dataSource': None, 'extractDate': '0001-01-0...
# 19  {'dataSource': None, 'extractDate': '0001-01-0...
# 20  {'dataSource': None, 'extractDate': '0001-01-0...
# 21  {'dataSource': None, 'extractDate': '0001-01-0...
# 22  {'dataSource': None, 'extractDate': '0001-01-0...
# 23  {'dataSource': None, 'extractDate': '0001-01-0...
# 24  {'dataSource': None, 'extractDate': '0001-01-0...
# 25  {'dataSource': None, 'extractDate': '0001-01-0...
# 26  {'dataSource': None, 'extractDate': '0001-01-0...
# 27  {'dataSource': None, 'extractDate': '0001-01-0...
# 28  {'dataSource': None, 'extractDate': '0001-01-0...
# 29  {'dataSource': None, 'extractDate': '0001-01-0...
# 30  {'dataSource': None, 'extractDate': '0001-01-0...
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links  \
# 0   [{'rel': 'self', 'href': 'https://api.ratings....
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 11  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 12  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 13  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 14  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 15  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 16  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 17  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 18  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 19  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 20  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 21  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 22  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 23  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 24  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 25  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 26  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 27  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 28  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 29  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 30  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                                    CO
# 0   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 1   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 2   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 3   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 4   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 5   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 6   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 7   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 8   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 9   {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 10  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 11  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 12  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 13  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 14  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 15  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 16  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 17  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 18  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 19  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 20  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 21  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 22  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 23  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 24  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 25  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 26  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 27  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 28  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 29  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 30  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 31  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 32  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
#
# [33 rows x 29 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Create the pipeline: match, then sort, then limit to 5
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {'geocode.latitude': {'$gte':latitude-degree_search, '$lte':latitude+degree_search},
         'geocode.longitude': {'$gte': longitude-degree_search, '$lte': longitude+degree_search},
         'RatingValue': 5}
sort = [('scores.Hygiene', 1)]
limit = 5

# Print the results
pprint(list(establishments.find(query).sort(sort).limit(limit)))
# Out:
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6676d2ec8b9d76c5040d7502'),
#   'geocode': {'latitude': Decimal128('51.4873437'),
#               'longitude': Decimal128('0.09208')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6676d2ec8b9d76c5040d751c'),
#   'geocode': {'latitude': Decimal128('51.481517791748'),
#               'longitude': Decimal128('0.0859939977526665')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '35 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Atlantic Fish Bar',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#   'ChangesByServerID': 0,
#   'Distance': 4646.974611855838,
#   'FHRSID': 694478,
#   'LocalAuthorityBusinessID': 'PI/000086506',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PR',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6676d2ec8b9d76c5040d751d'),
#   'geocode': {'latitude': Decimal128('51.4867296'),
#               'longitude': Decimal128('0.0912164')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6676d2ec8b9d76c5040d74d7'),
#   'geocode': {'latitude': Decimal128('51.4871482849121'),
#               'longitude': Decimal128('0.0924199968576431')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6676d2ec8b9d76c5040d74e7'),
#   'geocode': {'latitude': Decimal128('51.4875335693359'),
#               'longitude': Decimal128('0.0925370007753372')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
#17 Search within 0.01 degree on either side of the latitude and longitude.

# Set the latitude and longitude for the "Penang Flavours" restaurant
latitude = 51.49014200
longitude = 0.08384000

# Define the degree search radius
degree_search = 0.01

# Construct the query to find the top 5 establishments meeting the criteria
Penang_flavours_query = {
    'RatingValue': 5,
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search}
}

# Sort the results by hygiene score in ascending order
sort = [('scores.Hygiene', 1)]

#18 Rating value must equal 5
# Limit the results to the top 5 establishments
limit = 5

#19 Sort by hygiene score
Penang_flavours_query_results = establishments.find(Penang_flavours_query).sort(sort).limit(limit)

#20 Print the results
# Print the results
for result in Penang_flavours_query_results:
    pprint(result)
# Out:
# {'AddressLine1': '130 - 132 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Volunteer',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#  'ChangesByServerID': 0,
#  'Distance': 4646.965634598608,
#  'FHRSID': 694609,
#  'LocalAuthorityBusinessID': 'PI/000116619',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-08-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6676d2ec8b9d76c5040d7502'),
#  'geocode': {'latitude': Decimal128('51.4873437'),
#              'longitude': Decimal128('0.09208')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Plumstead Manor Nursery',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#  'ChangesByServerID': 0,
#  'Distance': 4646.9740101340385,
#  'FHRSID': 695241,
#  'LocalAuthorityBusinessID': 'PI/000179088',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1QG',
#  'RatingDate': '2021-06-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6676d2ec8b9d76c5040d751c'),
#  'geocode': {'latitude': Decimal128('51.481517791748'),
#              'longitude': Decimal128('0.0859939977526665')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '35 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Atlantic Fish Bar',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#  'ChangesByServerID': 0,
#  'Distance': 4646.974611855838,
#  'FHRSID': 694478,
#  'LocalAuthorityBusinessID': 'PI/000086506',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PR',
#  'RatingDate': '2021-06-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6676d2ec8b9d76c5040d751d'),
#  'geocode': {'latitude': Decimal128('51.4867296'),
#              'longitude': Decimal128('0.0912164')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '144 - 146 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Iceland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#  'ChangesByServerID': 0,
#  'Distance': 4646.946071297699,
#  'FHRSID': 695223,
#  'LocalAuthorityBusinessID': 'PI/000178842',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-11-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6676d2ec8b9d76c5040d74d7'),
#  'geocode': {'latitude': Decimal128('51.4871482849121'),
#              'longitude': Decimal128('0.0924199968576431')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'CO': {'DAILY_AQI_VALUE': None, 'PERCENT_COMPLETE': None},
#  'ChangesByServerID': 0,
#  'Distance': 4646.95593107927,
#  'FHRSID': 1380578,
#  'LocalAuthorityBusinessID': '14425',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SE',
#  'RatingDate': '2021-11-11T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6676d2ec8b9d76c5040d74e7'),
#  'geocode': {'latitude': Decimal128('51.4875335693359'),
#              'longitude': Decimal128('0.0925370007753372')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
#21 Convert result to Pandas DataFrame
# Initialize an empty list to store the query results
query_results_list = []

# Execute the query to find the top 5 establishments meeting the criteria
Penang_flavours_query_results = collection.find(Penang_flavours_query).sort(sort).limit(limit)

# Append the query results to the list
for result in Penang_flavours_query_results:
    query_results_list.append(result)

# Convert the query results list to a Pandas DataFrame
Penang_flavours_df = pd.DataFrame(query_results_list)

# Display the Pandas DataFrame
pprint(Penang_flavours_df)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6676d2ec8b9d76c5040d7502   694609                  0
# 1  6676d2ec8b9d76c5040d751c   695241                  0
# 2  6676d2ec8b9d76c5040d751d   694478                  0
# 3  6676d2ec8b9d76c5040d74d7   695223                  0
# 4  6676d2ec8b9d76c5040d74e7  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000086506                    Atlantic Fish Bar
# 3             PI/000178842                              Iceland
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2                 Takeaway/sandwich shop            7844
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                         Mobile caterer            7846
#
#                                         AddressLine1 AddressLine2  \
# 0                    130 - 132 Plumstead High Street
# 1               Plumstead Manor School Old Mill Road
# 2                                   35 Lakedale Road
# 3                    144 - 146 Plumstead High Street
# 4  Restaurant And Premises 107A Plumstead High St...
#
#   AddressLine3  ...    LocalAuthorityEmailAddress  \
# 0    Plumstead  ...  health@royalgreenwich.gov.uk
# 1    Plumstead  ...  health@royalgreenwich.gov.uk
# 2    Plumstead  ...  health@royalgreenwich.gov.uk
# 3    Plumstead  ...  health@royalgreenwich.gov.uk
# 4    Plumstead  ...  health@royalgreenwich.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.09208, 'latitude': 51.4873437}
# 1  {'longitude': 0.0859939977526665, 'latitude': ...
# 2   {'longitude': 0.0912164, 'latitude': 51.4867296}
# 3  {'longitude': 0.0924199968576431, 'latitude': ...
# 4  {'longitude': 0.0925370007753372, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4646.965635            False
# 1  4646.974010            False
# 2  4646.974612            False
# 3  4646.946071            False
# 4  4646.955931            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                                   CO
# 0  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 1  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 2  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 3  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
# 4  {'PERCENT_COMPLETE': None, 'DAILY_AQI_VALUE': ...
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
#22 Create a pipeline that:
#23 1. Matches establishments with a hygiene score of 0
#24 2. Groups the matches by Local Authority
#25 3. Sorts the matches from highest to lowest

#26 Print the number of documents in the result

#27 Print the first 10 results

# Define the aggregation pipeline
pipeline = [
    {"$match": {"RatingValue": 0}}, #23 1. Matches establishments with a hygiene score of 0
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}}, #24 2. Groups the matches by Local Authority
    {"$sort": {"count": -1}} #25 3. Sorts the matches from highest to lowest
]

# Execute the aggregation pipeline
pipeline_results = list(collection.aggregate(pipeline))

#26 Print the number of documents in the result
print("Number of documents in the result:", len(pipeline_results))

#27 Print the first 10 results
print("First 10 results:")
for result in pipeline_results[:10]:
    pprint(result)
# Out:
# Number of documents in the result: 23
# First 10 results:
# {'_id': 'Newham', 'count': 13}
# {'_id': 'Waltham Forest', 'count': 9}
# {'_id': 'Greenwich', 'count': 7}
# {'_id': 'Uttlesford', 'count': 6}
# {'_id': 'Redbridge', 'count': 4}
# {'_id': 'Barking and Dagenham', 'count': 4}
# {'_id': 'Tendring', 'count': 3}
# {'_id': 'Southend-On-Sea', 'count': 3}
# {'_id': 'Rochford', 'count': 2}
# {'_id': 'Canterbury City', 'count': 1}

# %%
#28 Convert the aggregation pipeline results to a Pandas DataFrame
pipeline_df = pd.DataFrame(pipeline_results)

#29 Display the number of rows in the DataFrame
print("Number of rows in the DataFrame:", len(pipeline_df))

#30 Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(pipeline_df.head(10))
# Out:
# Number of rows in the DataFrame: 23
# First 10 rows of the DataFrame:
#                     _id  count
# 0                Newham     13
# 1        Waltham Forest      9
# 2             Greenwich      7
# 3            Uttlesford      6
# 4             Redbridge      4
# 5  Barking and Dagenham      4
# 6              Tendring      3
# 7       Southend-On-Sea      3
# 8              Rochford      2
# 9       Canterbury City      1
